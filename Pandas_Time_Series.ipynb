# %% [markdown]
# <a href="https://colab.research.google.com/github/Akanksha10029/Python_Pandas/blob/main/Pandas_Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas Time Series: DateTimeIndex
import pandas as pd
df=pd.read_csv("/content/datetime_index_aapl.csv")
df.set_index("Date",inplace=True)
df
# Out:
#              Open    High     Low   Close    Volume
# Date
# 7-Jul-17   142.90  144.75  142.90  144.18  19201712
# 6-Jul-17   143.02  143.50  142.41  142.73  24128782
# 5-Jul-17   143.69  144.79  142.72  144.09  21569557
# 3-Jul-17   144.88  145.30  143.10  143.50  14277848
# 30-Jun-17  144.45  144.96  143.78  144.02  23024107
# ...           ...     ...     ...     ...       ...
# 15-Jul-16   98.92   99.30   98.50   98.78  30136990
# 14-Jul-16   97.39   98.99   97.32   98.79  38918997
# 13-Jul-16   97.41   97.67   96.84   96.87  25892171
# 12-Jul-16   97.17   97.70   97.12   97.42  24167463
# 11-Jul-16   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
import pandas as pd
df = pd.read_csv("/content/datetime_index_aapl.csv",parse_dates=["Date"], index_col="Date")
df.head(5)
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
# What is DatetimeIndex? Benefits of it:
# (1)Partial Date Index: Select Specific Months Data
df["2017-01"]
# Out:
# <ipython-input-19-45af6743d35c>:3: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2017-01"]
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673
# 2017-01-24  119.55  120.10  119.50  119.97  23211038
# 2017-01-23  120.00  120.81  119.77  120.08  22050218
# 2017-01-20  120.45  120.45  119.73  120.00  32597892
# 2017-01-19  119.40  120.09  119.37  119.78  25597291
# 2017-01-18  120.00  120.50  119.71  119.99  23712961
# 2017-01-17  118.34  120.24  118.22  120.00  34439843
# 2017-01-13  119.11  119.62  118.81  119.04  26111948
# ...

# %%
df["2017-01"].head()
# Out:
# <ipython-input-23-a298aad8c113>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2017-01"].head()
#               Open    High     Low   Close    Volume
# Date
# 2017-01-31  121.15  121.39  120.62  121.35  49200993
# 2017-01-30  120.93  121.63  120.66  121.63  30377503
# 2017-01-27  122.14  122.35  121.60  121.95  20562944
# 2017-01-26  121.67  122.44  121.60  121.94  26337576
# 2017-01-25  120.42  122.10  120.28  121.88  32586673

# %%
# Average price of aapl's stock in June, 2017
df["2017-06"].Close.mean()
# Out:
# <ipython-input-24-a12ff3b0eece>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2017-06"].Close.mean()
# 147.8313636363636

# %%
# median price of aapl's stock in march, 2017
df["2017-03"].Close.median()
# Out:
# <ipython-input-25-8bb96342ec50>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2017-03"].Close.median()
# 139.99

# %%
df["2017"].head()
# Out:
# <ipython-input-26-0454add08ca3>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2017"].head()
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
# (2) Select Date Range
df['2017-01-02':'2017-01-08']
# Out:
# <ipython-input-29-c6e0bdeeeb7a>:2: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df['2017-01-02':'2017-01-08']
#               Open    High     Low   Close    Volume
# Date
# 2017-01-06  116.78  118.16  116.47  117.91  31751900
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-03  115.80  116.33  114.76  116.15  28781865

# %%
# Resampling
# Freq: M means month like W for weekly,Q for quaterly etc and Name: Close i.e on the basis of Close we are evaluating the mean.
df['Close'].resample('M').mean().head()
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# Freq: M, Name: Close, dtype: float64

# %%
# %matplotlib inline
df["Open"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].resample("M").median().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].resample("Q").mean().plot()
# Out:
# <Axes: xlabel='Date'>
